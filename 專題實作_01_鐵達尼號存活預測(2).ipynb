# %% [markdown]
# <a href="https://colab.research.google.com/github/zy-shih/titanic-analysis/blob/main/%E5%B0%88%E9%A1%8C%E5%AF%A6%E4%BD%9C_01_%E9%90%B5%E9%81%94%E5%B0%BC%E8%99%9F%E5%AD%98%E6%B4%BB%E9%A0%90%E6%B8%AC(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# 讀取 CSV 檔案的函數，並將資料儲存於df中
df = pd.read_csv('https://raw.githubusercontent.com/dsindy/kaggle-titanic/master/data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# PassengerID: 乘客ID
# Survived: 是否存活(1:是/ 0:否)
# Pclass: 客艙等級(1=1st,2=2nd, 3=3rd)
# Name: 乘客姓名
# Sex:性別
# Age:年齡
# SibSp:船上兄弟姐妹/配偶數量
# Parch:船上父母/兒童數量
# Ticket:票號
# Fare:票價
# Cabin:客艙編碼
# Embarked:登船港口(C=瑟堡、Q=皇后鎮、S=南安普敦)

# %%
import pandas as pd

# 讀取資料集
df = pd.read_csv('https://raw.githubusercontent.com/dsindy/kaggle-titanic/master/data/train.csv')

# 將性別欄位轉換為數值 (male: 1, female: 0)
df['Sex'] = df['Sex'].map({'male': 1, 'female': 0})

# 選取需要的欄位
selected_columns = ['Pclass', 'Age', 'Sex', 'Survived']

# 丟棄 Age 欄位中的缺失值
df = df[selected_columns].dropna()

# 計算相關性矩陣
correlation_matrix = df.corr()


# 顯示與 Survived 的相關性
print(correlation_matrix['Survived'].sort_values(ascending=False))
# Out:
# Survived    1.000000
# Age        -0.077221
# Pclass     -0.359653
# Sex        -0.538826
# Name: Survived, dtype: float64

# %% [markdown]
# 客艙等級 = Pclass與生存率影響較大

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 視覺化 Pclass 與生存的關係
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title('Pclass vs Survived')
plt.show()

# 視覺化 Sex 與生存的關係
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title('Sex vs Survived')
plt.show()

# 視覺化 Age 與生存的關係
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack')
plt.title('Age vs Survived')
plt.show()
